# %%
import pandas as pd
import requests

# %%
df = pd.read_csv("top_600_combined.csv")
url_path = ("https://imdb-api.com/en/API/SearchMovie/k_br0y2jj3/")

# %%
df = pd.DataFrame(df)

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# ## Last row was 391.
# For next call, use df_func = df[491:591]

# %%
start = 491
end = 591

# %%
df_func = df[start:end]

# %%
df_func
# Out:
#      Rank                                Title  Lifetime Gross  Year  \
# 491   492                    The Polar Express       316897787  2004
# 492   493                     A Beautiful Mind       316791257  2001
# 493   494                    Beverly Hills Cop       316360478  1984
# 494   495                        Air Force One       315156409  1997
# 495   496                               Wonder       315025930  2017
# ..    ...                                  ...             ...   ...
# 586   587  Cloudy with a Chance of Meatballs 2       274325949  2013
# 587   588                  The Nutty Professor       273961019  1996
# 588   589                        Jerry Maguire       273552592  1996
# 589   590                          Bad Boys II       273339556  2003
# 590   591                        Lilo & Stitch       273144151  2002
#
#       Movie_id                                              Image    Director
# ...

# %%
for num, title in enumerate(df_func["Title"]):
    tit = df_func.loc[df_func["Movie_id"] == 0, "Title"]
    resp = requests.get(f"{url_path}{title}")
    resp_json1 = resp.json()
    id = resp_json1['results'][0]['id']
    image = resp_json1['results'][0]['image']
    print(id, title)
    df_func['Movie_id'][num:(num+1)] = id
    df_func['Image'][num:(num+1)] = image
# Out:
# tt0338348 The Polar Express
# C:\Users\olofs\AppData\Local\Temp\ipykernel_15428\1895295933.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_func['Movie_id'][num:(num+1)] = id
# C:\Users\olofs\AppData\Local\Temp\ipykernel_15428\1895295933.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_func['Image'][num:(num+1)] = image
# tt0268978 A Beautiful Mind
# tt0086960 Beverly Hills Cop
# tt0118571 Air Force One
# tt2543472 Wonder
# tt1764651 The Expendables 2
# tt0371606 Chicken Little
# tt0119822 As Good as It Gets
# tt8946378 Knives Out
# tt4046784 Maze Runner: The Scorch Trials
# ...

# %%
df_func.to_csv(f"{start}-{end}.csv")
