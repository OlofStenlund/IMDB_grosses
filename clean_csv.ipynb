# %%
import pandas as pd

# %%
# df = pd.read_csv("final_again.csv")

# %%
# df = df.drop(columns="Column1")
# df.fillna(0, inplace=True)

# %%
# df.rename(columns={"Lifetime Gross": "Lifetime_Gross"}, inplace=True)

# %%
# df.to_csv("Movies_final_1.csv")

# %%
# final1 = pd.read_csv("Movies_final_1.csv")

# %%
# final1
# Out:
#      Unnamed: 0  Rank                                       Title  \
# 0             0     1                                      Avatar
# 1             1     2                           Avengers: Endgame
# 2             2     3                    Avatar: The Way of Water
# 3             3     4                                     Titanic
# 4             4     5  Star Wars: Episode VII - The Force Awakens
# ..          ...   ...                                         ...
# 595         595   596                                    The Firm
# 596         596   597                           We're the Millers
# 597         597   598                                 Gran Torino
# 598         598   599                                   10,000 BC
# 599         599   600                           American Gangster
#
#      Lifetime_Gross  Year   Movie_id  \
# 0        2923706026  2009  tt1630029
# 1        2799439100  2019  tt4154796
# 2        2318325624  2022  tt1630029
# ...

# %%
# final1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      600 non-null    int64
#  1   Rank            600 non-null    int64
#  2   Title           600 non-null    object
#  3   Lifetime_Gross  600 non-null    int64
#  4   Year            600 non-null    int64
#  5   Movie_id        600 non-null    object
#  6   Image           600 non-null    object
#  7   Director        600 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 37.6+ KB

# %%
data = pd.read_csv("Movies_final_1.csv")
df = pd.DataFrame(data)
df.drop(columns="Unnamed: 0", inplace=True)
df
# Out:
#      Rank                                       Title  Lifetime_Gross  Year  \
# 0       1                                      Avatar      2923706026  2009
# 1       2                           Avengers: Endgame      2799439100  2019
# 2       3                    Avatar: The Way of Water      2318325624  2022
# 3       4                                     Titanic      2264162353  1997
# 4       5  Star Wars: Episode VII - The Force Awakens      2071310218  2015
# ..    ...                                         ...             ...   ...
# 595   596                                    The Firm       270248367  1993
# 596   597                           We're the Millers       269994119  2012
# 597   598                                 Gran Torino       269958228  2008
# 598   599                                   10,000 BC       269784201  2008
# 599   600                           American Gangster       269755430  2007
#
# ...

# %%
for num, movie in df.iterrows():
    rank = movie["Rank"]
    title = movie["Title"]
    lifetimegross = movie["Lifetime_Gross"]
    year = movie["Year"]
    movie_id = movie["Movie_id"]
    image = movie["Image"]
    director = movie["Director"]
    # print(rank, title, lifetimegross, year, movie_id, image, director)
    db.call_db(insert_movie, mov["Rank"], mov["Title"], mov["Lifetime_Gross"], mov["Year"], mov["Movie_id"], mov["Image"], mov["Director"])
# Out:
# 1 Avatar 2923706026 2009 tt1630029 0 0
